# %%
# %%capture
# !pip install pandasai

# %%
import os
#use your PandasAPI Key, you can generate one here:
# https://github.com/sinaptik-ai/pandas-ai Official Github
os.environ['PANDASAI_API_KEY'] = "$2a$10$T.VSq86EOyINCT69k.PfA.vHO9AC/geSKnFGGTFK8Rb8z4g9olPlu"

# %%
from pandasai.connectors.yahoo_finance import YahooFinanceConnector
from pandasai import SmartDataframe

yahoo_connector = YahooFinanceConnector("BTC-USD")
df = SmartDataframe(yahoo_connector)
#prices depicted should be multipied by 1000 for BTC.
response = df.chat("Plot the chart of the stock")
print(response)
# Out:
# ERROR:yfinance:BTC-USD: Period '3d' is invalid, must be one of ['1d', '5d', '1mo', '3mo', '6mo', '1y', '2y', '5y', '10y', 'ytd', 'max']
# /content/exports/charts/temp_chart.png

# %%
from pandasai import Agent

yahoo_connector = YahooFinanceConnector("BTC-USD")

agent = Agent(yahoo_connector)
response = agent.chat("Plot the chart of the stock close price")
# Out:
# ERROR:yfinance:BTC-USD: Period '3d' is invalid, must be one of ['1d', '5d', '1mo', '3mo', '6mo', '1y', '2y', '5y', '10y', 'ytd', 'max']

# %%
result = agent.chat("Can you also add the 20 days moving average at 1000 days?")

# %%
result = agent.chat("Plot a bar chart of closing price and low for last 20 days")
